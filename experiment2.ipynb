# %%
a = 30
b = 20
if a<b:
    print("yerss ekhf")

# %%
len ("harsh")
# Out:
# 5

# %%
a = 12
type(a)
# Out:
# int

# %%
name = "harsh"
print(type(name))
# Out:
# <class 'str'>

# %%
a = [2,"harsh",3.4, True]
b = (6,7,8,9)
print(type(a))
print(type(b))
print(list(a))
for item in a:
    print(item, type(item))
# Out:
# <class 'list'>
# <class 'tuple'>
# [2, 'harsh', 3.4, True]
# 2 <class 'int'>
# harsh <class 'str'>
# 3.4 <class 'float'>
# True <class 'bool'>

# %%
a = [2,3,4,5]
print(type(a))

b = (1,"harsh",3.2,True)
for item in b:
    print(item,type(item))
# Out:
# <class 'list'>
# 1 <class 'int'>
# harsh <class 'str'>
# 3.2 <class 'float'>
# True <class 'bool'>

# %%
name = "harsh"
print("harsh".upper())
# Out:
# HARSH

# %%
name = "harsh"
print(type(name))
# Out:
# <class 'str'>

# %%
print(True + True)
print(False + True)
# Out:
# 2
# 1
